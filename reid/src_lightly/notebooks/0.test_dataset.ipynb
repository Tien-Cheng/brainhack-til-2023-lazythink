# %%
# %cd ..
# Out:
# /home/kiritowu/code/brainhack-til-2023-lazythink/reid/lightly

# %%
from data import YoloPlushieDataset

train_yolo_dataset = YoloPlushieDataset(
    "../../od/data",
    "images/train",
    "labels/yolo/train_labels"
)

validation_yolo_dataset = YoloPlushieDataset(
    "../../od/data",
    "images/validation",
    "labels/yolo/val_labels"
)

# %%
import matplotlib.pyplot as plt

dt = iter(train_yolo_dataset)

# %%
img, target = next(dt)

plt.imshow(img)
plt.title(target)
# Out:
# Text(0.5, 1.0, '165')

# %%
from lightly.data import LightlyDataset
from lightly.transforms.simclr_transform import SimCLRTransform
transform = SimCLRTransform(input_size=32)
dataset = LightlyDataset.from_torch_dataset(train_yolo_dataset, transform=transform)

# %%
dt = iter(dataset)

nani = next(dt)

# %%
import matplotlib.pyplot as plt

img, label, wat = next(dt)

plt.imshow(img[0].permute(1, 2, 0))
plt.show()

plt.imshow(img[1].permute(1, 2, 0))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
