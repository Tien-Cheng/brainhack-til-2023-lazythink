# %% [markdown]
# # Installing Dependencies

# %%
# %%bash
#
# # Install mim engine
# pip install -U openmim
# mim install mmengine
# mim install "mmcv>=2.0.0"
#
# # Clone private repo
# export GITHUB_USER=kiritowu
# export GITHUB_TOKEN=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
# export GITHUB_REPOSITORY=Tien-Cheng/brainhack-til-2023-lazythink
# git clone https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/${GITHUB_REPOSITORY}
# cd brainhack-til-2023-lazythink/od
#
# # Install mmdet
# git clone https://github.com/open-mmlab/mmdetection.git
# cd mmdetection
# pip install -v -e .
# cd ..

# %%
# !gcloud auth login

# %% [markdown]
# # Preparing Dataset

# %%
# !mkdir ~/Downloads
# !gsutil cp gs://cloud-ai-platform-e8edc327-855c-4911-bb8e-205517f8c899/cv/Train.zip ~/Downloads/Train.zip
# !gsutil cp gs://cloud-ai-platform-e8edc327-855c-4911-bb8e-205517f8c899/cv/Validation.zip ~/Downloads/Valid.zip
# Out:
# Copying gs://cloud-ai-platform-e8edc327-855c-4911-bb8e-205517f8c899/cv/Validation.zip...
# - [1 files][535.6 MiB/535.6 MiB]   54.4 MiB/s
# Operation completed over 1 objects/535.6 MiB.

# %% [markdown]
# ## Unzip Files to Relevant Directories

# %%
# %cd ..
# Out:
# /root/brainhack-til-2023-lazythink/od

# %%
# !mkdir data/images

# %%
# !unzip -q -o ~/Downloads/Train.zip -d data/images/train
# !unzip -q -o ~/Downloads/Valid.zip -d data/images/validation

# %% [markdown]
# # Model Training

# %%
# !PYTHONPATH=./ python mmdetection/tools/train.py \
    configs/rtmdet/rtmdet_l_8xb32-300e_coco.py
# Out:
# 05/20 18:09:33 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1580056899
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 05/20 18:09:34 - mmengine - INFO - Config:
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=10, max_keep_ckpts=3),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = 'https://download.openmmlab.com/mmdetection/v3.0/rtmdet/rtmdet_l_8xb32-300e_coco/rtmdet_l_8xb32-300e_coco_20220719_112030-5a0be7c4.pth'
# resume = False
# train_cfg = dict(
#     type='EpochBasedTrainLoop',
#     max_epochs=300,
#     val_interval=10,
#     dynamic_intervals=[(280, 1)])
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-05, by_epoch=False, begin=0,
#         end=1000),
#     dict(
#         type='CosineAnnealingLR',
#         eta_min=0.0002,
#         begin=150,
#         end=300,
#         T_max=150,
#         by_epoch=True,
#         convert_to_iter_based=True)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='AdamW', lr=0.004, weight_decay=0.05),
#     paramwise_cfg=dict(
#         norm_decay_mult=0, bias_decay_mult=0, bypass_duplicate=True))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# dataset_type = 'CocoDataset'
# data_root = 'data/'
# classes = 'plushie'
# backend_args = None
# custom_imports = dict(
#     imports=['configs.custom_transform'], allow_failed_imports=False)
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='CachedMosaic', img_scale=(640, 640), pad_val=114.0),
#     dict(
#         type='RandomResize',
#         scale=(1280, 1280),
#         ratio_range=(0.1, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(640, 640)),
#     dict(type='YOLOXHSVRandomAug'),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='Pad', size=(640, 640), pad_val=dict(img=(114, 114, 114))),
#     dict(
#         type='CachedMixUp',
#         img_scale=(640, 640),
#         ratio_range=(1.0, 1.0),
#         max_cached_images=20,
#         pad_val=(114, 114, 114)),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(640, 640), keep_ratio=True),
#     dict(type='Pad', size=(640, 640), pad_val=dict(img=(114, 114, 114))),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=16,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     dataset=dict(
#         type='CocoDataset',
#         metainfo=dict(classes='plushie'),
#         data_root='data/',
#         ann_file='labels-train.json',
#         data_prefix=dict(img='images/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='CachedMosaic', img_scale=(640, 640), pad_val=114.0),
#             dict(
#                 type='RandomResize',
#                 scale=(1280, 1280),
#                 ratio_range=(0.1, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(640, 640)),
#             dict(type='YOLOXHSVRandomAug'),
#             dict(type='RandomFlip', prob=0.5),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(
#                 type='CachedMixUp',
#                 img_scale=(640, 640),
#                 ratio_range=(1.0, 1.0),
#                 max_cached_images=20,
#                 pad_val=(114, 114, 114)),
#             dict(type='PackDetInputs')
#         ]),
#     batch_sampler=None,
#     pin_memory=True)
# val_dataloader = dict(
#     batch_size=5,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         test_mode=True,
#         metainfo=dict(classes='plushie'),
#         data_root='data/',
#         ann_file='labels-val.json',
#         data_prefix=dict(img='images/validation'),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(640, 640), keep_ratio=True),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ]))
# test_dataloader = dict(
#     batch_size=5,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     dataset=dict(
#         type='CocoDataset',
#         test_mode=True,
#         metainfo=dict(classes='plushie'),
#         data_root='data/',
#         ann_file='labels-test.json',
#         data_prefix=dict(img='images/test'),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(640, 640), keep_ratio=True),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ]))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file='data//labels-val.json',
#     metric='bbox',
#     backend_args=None,
#     proposal_nums=(100, 1, 10))
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file='data//labels-test.json',
#     metric='bbox',
#     format_only=True,
#     outfile_prefix='./work_dirs/coco_detection/test',
#     proposal_nums=(100, 1, 10))
# tta_model = dict(
#     type='DetTTAModel',
#     tta_cfg=dict(nms=dict(type='nms', iou_threshold=0.6), max_per_img=100))
# img_scales = [(640, 640), (320, 320), (960, 960)]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale': (640, 640),
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale': (320, 320),
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale': (960, 960),
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 1.0
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 0.0
#                     }],
#                     [{
#                         'type': 'Pad',
#                         'size': (960, 960),
#                         'pad_val': {
#                             'img': (114, 114, 114)
#                         }
#                     }],
#                     [{
#                         'type':
#                         'PackDetInputs',
#                         'meta_keys':
#                         ('img_id', 'img_path', 'ori_shape', 'img_shape',
#                          'scale_factor', 'flip', 'flip_direction')
#                     }]])
# ]
# model = dict(
#     type='RTMDet',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[103.53, 116.28, 123.675],
#         std=[57.375, 57.12, 58.395],
#         bgr_to_rgb=False,
#         batch_augments=None),
#     backbone=dict(
#         type='CSPNeXt',
#         arch='P5',
#         expand_ratio=0.5,
#         deepen_factor=1,
#         widen_factor=1,
#         channel_attention=True,
#         norm_cfg=dict(type='SyncBN'),
#         act_cfg=dict(type='SiLU', inplace=True)),
#     neck=dict(
#         type='CSPNeXtPAFPN',
#         in_channels=[256, 512, 1024],
#         out_channels=256,
#         num_csp_blocks=3,
#         expand_ratio=0.5,
#         norm_cfg=dict(type='SyncBN'),
#         act_cfg=dict(type='SiLU', inplace=True)),
#     bbox_head=dict(
#         type='RTMDetSepBNHead',
#         num_classes=1,
#         in_channels=256,
#         stacked_convs=2,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='MlvlPointGenerator', offset=0, strides=[8, 16, 32]),
#         bbox_coder=dict(type='DistancePointBBoxCoder'),
#         loss_cls=dict(
#             type='QualityFocalLoss',
#             use_sigmoid=True,
#             beta=2.0,
#             loss_weight=1.0),
#         loss_bbox=dict(type='GIoULoss', loss_weight=2.0),
#         with_objectness=False,
#         exp_on_reg=True,
#         share_conv=True,
#         pred_kernel_size=1,
#         norm_cfg=dict(type='SyncBN'),
#         act_cfg=dict(type='SiLU', inplace=True)),
#     train_cfg=dict(
#         assigner=dict(type='DynamicSoftLabelAssigner', topk=13),
#         allowed_border=-1,
#         pos_weight=-1,
#         debug=False),
#     test_cfg=dict(
#         nms_pre=30000,
#         min_bbox_size=0,
#         score_thr=0.001,
#         nms=dict(type='nms', iou_threshold=0.65),
#         max_per_img=300))
# train_pipeline_stage2 = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='RandomResize',
#         scale=(640, 640),
#         ratio_range=(0.1, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(640, 640)),
#     dict(type='YOLOXHSVRandomAug'),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='Pad', size=(640, 640), pad_val=dict(img=(114, 114, 114))),
#     dict(type='PackDetInputs')
# ]
# max_epochs = 300
# stage2_num_epochs = 20
# base_lr = 0.004
# interval = 10
# custom_hooks = [
#     dict(
#         type='EMAHook',
#         ema_type='ExpMomentumEMA',
#         momentum=0.0002,
#         update_buffers=True,
#         priority=49),
#     dict(
#         type='PipelineSwitchHook',
#         switch_epoch=280,
#         switch_pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='RandomResize',
#                 scale=(640, 640),
#                 ratio_range=(0.1, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(640, 640)),
#             dict(type='YOLOXHSVRandomAug'),
#             dict(type='RandomFlip', prob=0.5),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(type='PackDetInputs')
#         ])
# ]
# launcher = 'none'
# work_dir = './work_dirs/rtmdet_l_8xb32-300e_coco'
# 05/20 18:09:39 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 05/20 18:09:39 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) PipelineSwitchHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 05/20 18:09:40 - mmengine - WARNING - plushie is not a meta file, simply parsed as meta information
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.2.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.2.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage1.1.attention.fc.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.4.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.4.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.4.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.4.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.4.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.4.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.5.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.5.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.5.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.5.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.5.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.5.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage2.1.attention.fc.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.4.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.4.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.4.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.4.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.4.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.4.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.5.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.5.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.5.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.5.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.5.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.5.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage3.1.attention.fc.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.2.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.2.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- backbone.stage4.2.attention.fc.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.reduce_layers.0.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.reduce_layers.0.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.reduce_layers.1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.reduce_layers.1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.main_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.main_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.short_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.short_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.final_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.final_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.2.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.2.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.main_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.main_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.short_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.short_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.final_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.final_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.2.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.2.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.downsamples.0.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.downsamples.0.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.downsamples.1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.downsamples.1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.main_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.main_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.short_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.short_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.final_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.final_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.2.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.2.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.main_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.main_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.short_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.short_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.final_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.final_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 05/20 18:09:40 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# ...
# 05/21 03:04:52 - mmengine - INFO - Epoch(train)  [91][250/354]  lr: 4.0000e-03  eta: 20:21:06  time: 0.9864  data_time: 0.0772  memory: 21422  loss: 0.2644  loss_cls: 0.0937  loss_bbox: 0.1707
# 05/21 03:05:40 - mmengine - INFO - Epoch(train)  [91][300/354]  lr: 4.0000e-03  eta: 20:20:14  time: 0.9641  data_time: 0.0603  memory: 21422  loss: 0.2540  loss_cls: 0.0836  loss_bbox: 0.1704
# 05/21 03:06:29 - mmengine - INFO - Epoch(train)  [91][350/354]  lr: 4.0000e-03  eta: 20:19:23  time: 0.9783  data_time: 0.0664  memory: 21422  loss: 0.2598  loss_cls: 0.0866  loss_bbox: 0.1733
# 05/21 03:06:32 - mmengine - INFO - Exp name: rtmdet_l_8xb32-300e_coco_20230520_180932
# 05/21 03:07:26 - mmengine - INFO - Epoch(train)  [92][ 50/354]  lr: 4.0000e-03  eta: 20:18:39  time: 1.0744  data_time: 0.1713  memory: 21422  loss: 0.2572  loss_cls: 0.0880  loss_bbox: 0.1692
# 05/21 03:08:15 - mmengine - INFO - Epoch(train)  [92][100/354]  lr: 4.0000e-03  eta: 20:17:47  time: 0.9720  data_time: 0.0668  memory: 21422  loss: 0.2561  loss_cls: 0.0861  loss_bbox: 0.1700
# 05/21 03:09:04 - mmengine - INFO - Epoch(train)  [92][150/354]  lr: 4.0000e-03  eta: 20:16:58  time: 0.9886  data_time: 0.0803  memory: 21422  loss: 0.2486  loss_cls: 0.0822  loss_bbox: 0.1664
# 05/21 03:09:53 - mmengine - INFO - Epoch(train)  [92][200/354]  lr: 4.0000e-03  eta: 20:16:07  time: 0.9817  data_time: 0.0724  memory: 21422  loss: 0.2388  loss_cls: 0.0774  loss_bbox: 0.1614
# 05/21 03:10:43 - mmengine - INFO - Epoch(train)  [92][250/354]  lr: 4.0000e-03  eta: 20:15:18  time: 0.9864  data_time: 0.0808  memory: 21422  loss: 0.2716  loss_cls: 0.0938  loss_bbox: 0.1778
# 05/21 03:11:32 - mmengine - INFO - Epoch(train)  [92][300/354]  lr: 4.0000e-03  eta: 20:14:27  time: 0.9817  data_time: 0.0822  memory: 21422  loss: 0.2590  loss_cls: 0.0867  loss_bbox: 0.1723
# 05/21 03:12:20 - mmengine - INFO - Epoch(train)  [92][350/354]  lr: 4.0000e-03  eta: 20:13:36  time: 0.9738  data_time: 0.0665  memory: 21422  loss: 0.2616  loss_cls: 0.0882  loss_bbox: 0.1734
# 05/21 03:12:24 - mmengine - INFO - Exp name: rtmdet_l_8xb32-300e_coco_20230520_180932
# 05/21 03:13:17 - mmengine - INFO - Epoch(train)  [93][ 50/354]  lr: 4.0000e-03  eta: 20:12:50  time: 1.0636  data_time: 0.1549  memory: 21422  loss: 0.2545  loss_cls: 0.0853  loss_bbox: 0.1692
# 05/21 03:14:05 - mmengine - INFO - Epoch(train)  [93][100/354]  lr: 4.0000e-03  eta: 20:11:57  time: 0.9608  data_time: 0.0589  memory: 21422  loss: 0.2566  loss_cls: 0.0850  loss_bbox: 0.1715
# 05/21 03:14:54 - mmengine - INFO - Epoch(train)  [93][150/354]  lr: 4.0000e-03  eta: 20:11:07  time: 0.9832  data_time: 0.0703  memory: 21422  loss: 0.2577  loss_cls: 0.0872  loss_bbox: 0.1705
# 05/21 03:15:43 - mmengine - INFO - Epoch(train)  [93][200/354]  lr: 4.0000e-03  eta: 20:10:15  time: 0.9626  data_time: 0.0479  memory: 21422  loss: 0.2628  loss_cls: 0.0924  loss_bbox: 0.1704
# 05/21 03:16:31 - mmengine - INFO - Epoch(train)  [93][250/354]  lr: 4.0000e-03  eta: 20:09:23  time: 0.9628  data_time: 0.0548  memory: 21422  loss: 0.2424  loss_cls: 0.0795  loss_bbox: 0.1629
# 05/21 03:17:21 - mmengine - INFO - Epoch(train)  [93][300/354]  lr: 4.0000e-03  eta: 20:08:35  time: 1.0073  data_time: 0.0998  memory: 21422  loss: 0.2514  loss_cls: 0.0830  loss_bbox: 0.1684
# 05/21 03:18:09 - mmengine - INFO - Epoch(train)  [93][350/354]  lr: 4.0000e-03  eta: 20:07:42  time: 0.9588  data_time: 0.0472  memory: 21422  loss: 0.2524  loss_cls: 0.0837  loss_bbox: 0.1688
# 05/21 03:18:13 - mmengine - INFO - Exp name: rtmdet_l_8xb32-300e_coco_20230520_180932
# 05/21 03:19:05 - mmengine - INFO - Epoch(train)  [94][ 50/354]  lr: 4.0000e-03  eta: 20:06:54  time: 1.0453  data_time: 0.1455  memory: 21422  loss: 0.2595  loss_cls: 0.0870  loss_bbox: 0.1724
# 05/21 03:19:32 - mmengine - INFO - Exp name: rtmdet_l_8xb32-300e_coco_20230520_180932
# 05/21 03:19:53 - mmengine - INFO - Epoch(train)  [94][100/354]  lr: 4.0000e-03  eta: 20:06:02  time: 0.9652  data_time: 0.0557  memory: 21422  loss: 0.2527  loss_cls: 0.0827  loss_bbox: 0.1700
# 05/21 03:20:42 - mmengine - INFO - Epoch(train)  [94][150/354]  lr: 4.0000e-03  eta: 20:05:11  time: 0.9693  data_time: 0.0658  memory: 21422  loss: 0.2485  loss_cls: 0.0842  loss_bbox: 0.1643
# 05/21 03:21:31 - mmengine - INFO - Epoch(train)  [94][200/354]  lr: 4.0000e-03  eta: 20:04:20  time: 0.9788  data_time: 0.0660  memory: 21422  loss: 0.2395  loss_cls: 0.0781  loss_bbox: 0.1614
# 05/21 03:22:21 - mmengine - INFO - Epoch(train)  [94][250/354]  lr: 4.0000e-03  eta: 20:03:32  time: 1.0043  data_time: 0.0532  memory: 21422  loss: 0.2552  loss_cls: 0.0862  loss_bbox: 0.1690
# 05/21 03:23:12 - mmengine - INFO - Epoch(train)  [94][300/354]  lr: 4.0000e-03  eta: 20:02:46  time: 1.0174  data_time: 0.0445  memory: 21422  loss: 0.2566  loss_cls: 0.0871  loss_bbox: 0.1695
# 05/21 03:24:01 - mmengine - INFO - Epoch(train)  [94][350/354]  lr: 4.0000e-03  eta: 20:01:56  time: 0.9826  data_time: 0.0589  memory: 21422  loss: 0.2467  loss_cls: 0.0794  loss_bbox: 0.1673
# 05/21 03:24:05 - mmengine - INFO - Exp name: rtmdet_l_8xb32-300e_coco_20230520_180932
# 05/21 03:24:57 - mmengine - INFO - Epoch(train)  [95][ 50/354]  lr: 4.0000e-03  eta: 20:01:08  time: 1.0442  data_time: 0.1455  memory: 21422  loss: 0.2641  loss_cls: 0.0928  loss_bbox: 0.1714
# 05/21 03:25:46 - mmengine - INFO - Epoch(train)  [95][100/354]  lr: 4.0000e-03  eta: 20:00:17  time: 0.9774  data_time: 0.0592  memory: 21422  loss: 0.2587  loss_cls: 0.0868  loss_bbox: 0.1719
# 05/21 03:26:34 - mmengine - INFO - Epoch(train)  [95][150/354]  lr: 4.0000e-03  eta: 19:59:24  time: 0.9552  data_time: 0.0545  memory: 21422  loss: 0.2519  loss_cls: 0.0848  loss_bbox: 0.1672
# 05/21 03:27:23 - mmengine - INFO - Epoch(train)  [95][200/354]  lr: 4.0000e-03  eta: 19:58:34  time: 0.9823  data_time: 0.0775  memory: 21422  loss: 0.2662  loss_cls: 0.0911  loss_bbox: 0.1751
# 05/21 03:28:13 - mmengine - INFO - Epoch(train)  [95][250/354]  lr: 4.0000e-03  eta: 19:57:45  time: 0.9904  data_time: 0.0850  memory: 21422  loss: 0.2585  loss_cls: 0.0881  loss_bbox: 0.1704
# 05/21 03:29:01 - mmengine - INFO - Epoch(train)  [95][300/354]  lr: 4.0000e-03  eta: 19:56:54  time: 0.9761  data_time: 0.0661  memory: 21422  loss: 0.2521  loss_cls: 0.0836  loss_bbox: 0.1686
# 05/21 03:29:50 - mmengine - INFO - Epoch(train)  [95][350/354]  lr: 4.0000e-03  eta: 19:56:02  time: 0.9711  data_time: 0.0677  memory: 21422  loss: 0.2630  loss_cls: 0.0904  loss_bbox: 0.1726
# 05/21 03:29:54 - mmengine - INFO - Exp name: rtmdet_l_8xb32-300e_coco_20230520_180932
# 05/21 03
- mmengine - INFO - Exp name: rtmdet_l_8xb32-300e_coco_20230520_180932
# 05/21 03:53:11 - mmengine - INFO - Epoch(train)  [99][350/354]  lr: 4.0000e-03  eta: 19:32:41  time: 0.9462  data_time: 0.0283  memory: 21422  loss: 0.2527  loss_cls: 0.0864  loss_bbox: 0.1663
# 05/21 03:53:14 - mmengine - INFO - Exp name: rtmdet_l_8xb32-300e_coco_20230520_180932
# 05/21 03:54:08 - mmengine - INFO - Epoch(train) [100][ 50/354]  lr: 4.0000e-03  eta: 19:31:55  time: 1.0759  data_time: 0.1695  memory: 21422  loss: 0.2689  loss_cls: 0.0932  loss_bbox: 0.1757
# 05/21 03:54:57 - mmengine - INFO - Epoch(train) [100][100/354]  lr: 4.0000e-03  eta: 19:31:05  time: 0.9808  data_time: 0.0811  memory: 21422  loss: 0.2486  loss_cls: 0.0823  loss_bbox: 0.1664
# 05/21 03:55:46 - mmengine - INFO - Epoch(train) [100][150/354]  lr: 4.0000e-03  eta: 19:30:13  time: 0.9685  data_time: 0.0601  memory: 21422  loss: 0.2445  loss_cls: 0.0816  loss_bbox: 0.1630
# 05/21 03:56:35 - mmengine - INFO - Epoch(train) [100][200/354]  lr: 4.0000e-03  eta: 19:29:24  time: 0.9872  data_time: 0.0763  memory: 21422  loss: 0.2522  loss_cls: 0.0821  loss_bbox: 0.1701
# 05/21 03:57:24 - mmengine - INFO - Epoch(train) [100][250/354]  lr: 4.0000e-03  eta: 19:28:34  time: 0.9901  data_time: 0.0925  memory: 21422  loss: 0.2688  loss_cls: 0.0934  loss_bbox: 0.1754
# 05/21 03:58:13 - mmengine - INFO - Epoch(train) [100][300/354]  lr: 4.0000e-03  eta: 19:27:42  time: 0.9633  data_time: 0.0499  memory: 21422  loss: 0.2491  loss_cls: 0.0840  loss_bbox: 0.1650
# 05/21 03:59:01 - mmengine - INFO - Epoch(train) [100][350/354]  lr: 4.0000e-03  eta: 19:26:50  time: 0.9609  data_time: 0.0418  memory: 21422  loss: 0.2460  loss_cls: 0.0805  loss_bbox: 0.1655
# 05/21 03:59:04 - mmengine - INFO - Exp name: rtmdet_l_8xb32-300e_coco_20230520_180932
# 05/21 03:59:04 - mmengine - INFO - Saving checkpoint at 100 epochs
# 05/21 03:59:13 - mmengine - INFO - Epoch(val) [100][ 50/160]    eta: 0:00:11  time: 0.1002  data_time: 0.0107  memory: 21422
# 05/21 03:59:17 - mmengine - INFO - Epoch(val) [100][100/160]    eta: 0:00:05  time: 0.0964  data_time: 0.0070  memory: 1273
# 05/21 03:59:23 - mmengine - INFO - Epoch(val) [100][150/160]    eta: 0:00:01  time: 0.1062  data_time: 0.0096  memory: 1273
# 05/21 03:59:30 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=1.10s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=7.48s).
# Accumulating evaluation results...
# DONE (t=0.97s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.860
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.974
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.803
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.862
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.433
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.895
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.895
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.841
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.898
# 05/21 03:59:41 - mmengine - INFO - bbox_mAP_copypaste: 0.860 0.990 0.974 -1.000 0.803 0.862
# 05/21 03:59:42 - mmengine - INFO - Epoch(val) [100][160/160]    coco/bbox_mAP: 0.8600  coco/bbox_mAP_50: 0.9900  coco/bbox_mAP_75: 0.9740  coco/bbox_mAP_s: -1.0000  coco/bbox_mAP_m: 0.8030  coco/bbox_mAP_l: 0.8620  data_time: 0.0093  time: 0.1015
